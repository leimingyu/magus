# %% [raw]
# read test_cases/benchmark.result_iter100_modify

# %%
# app name in the result_iter100

app_list = ['convfft2d', 
            'interval', 
            'reduction', 
            'scan', 
            'binopt', 
            'radixSortThrust', 
            'MCSingleAsianOptionP',
            'quasirandomGenerator', 
            'mergeSort' , 
            'transpose', 
            'sortingNetworks', 
            'matrixMul', 
            'SobolQRNG']

print len(app_list)

single_exe = {}
single_exe['MCSingleAsianOptionP'] = 494.83
single_exe['binopt'] = 25347
single_exe['scan'] = 2650.76
single_exe['radixSortThrust'] = 3228.42
single_exe['transpose'] = 743.9
single_exe['quasirandomGenerator'] = 1192.34
single_exe['sortingNetworks'] = 5819.04
single_exe['matrixMul'] = 481.79
single_exe['reduction'] = 1160.41
single_exe['SobolQRNG'] = 659.2
single_exe['interval'] = 2061.01
single_exe['convfft2d'] = 3927.42
single_exe['mergeSort'] = 873.77

print len(single_exe)
# Out:
# 13
# 13

# %%
import re
import sys

# dict of lists
from collections import defaultdict
result_dlist = defaultdict(list)

with open("test_cases/benchmark.result_iter100_modify", "r") as File:
    for line in File:
        slowndown_dd = {}
        # sep line with :
        print line
        
        [part1, part2] = re.split(": \t", line)
        #print part1
        
        
        #---------------
        # extract app name
        #---------------
        [app1, app2] = re.split("_", part1)
#         sep_loc = part1.index("_")
#         app1 = part1[:sep_loc]
#         app2 = part1[sep_loc+1:]
        print app1
        print app2
        
        if app1 not in app_list or app2 not in app_list:
            print line
            print "app name not in the list"
            sys.exit(1)
            
        #---------------
        # extract app runtime
        #---------------
        
        [app1_str, app2_str]= re.split("\t", part2)
        #print app1_str, app2_str
        # extract decimals from string
        app1_runtime = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", app1_str.split(":")[1])
#         print type(app1_runtime)
        app1_runtime = float(app1_runtime[0])
        
        app2_runtime = re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", app2_str.split(":")[1])
        app2_runtime = float(app2_runtime[0])
        
        print app1_runtime, app2_runtime
        
        app1_slowdown = app1_runtime / single_exe[app1] - 1.
        app2_slowdown = app2_runtime / single_exe[app2] - 1.
        
        print app1_slowdown, app2_slowdown

        app1and2 = app1 + "+" + app2
        #print app1and2
        
        slowndown_dd[app1and2] = [app1, app1_slowdown, app2, app2_slowdown] 
        
        result_dlist[app1].append(slowndown_dd)
# Out:
# convfft2d_interval: 	convfft2d: 4561.16	interval: 2564.76
#
# convfft2d
# interval
# 4561.16 2564.76
# 0.161362930372 0.244418998452
# reduction_scan: 	reduction: 1756.41	scan: 3071.92
#
# reduction
# scan
# 1756.41 3071.92
# 0.513611568325 0.158882735517
# binopt_reduction: 	binopt: 25607.2	reduction: 1412.55
#
# binopt
# reduction
# 25607.2 1412.55
# 0.0102655146566 0.217285269862
# radixSortThrust_scan: 	radixSortThrust: 4884.62	scan: 4005.21
#
# radixSortThrust
# scan
# 4884.62 4005.21
# 0.513006362245 0.510966666164
# convfft2d_MCSingleAsianOptionP: 	convfft2d: 4374.93	MCSingleAsianOptionP: 925.49
#
# convfft2d
# MCSingleAsianOptionP
# 4374.93 925.49
# 0.113945032617 0.870319099489
# radixSortThrust_reduction: 	radixSortThrust: 3857.12	reduction: 1863.66
#
# radixSortThrust
# reduction
# 3857.12 1863.66
# 0.194739222282 0.606035797692
# quasirandomGenerator_mergeSort: 	quasirandomGenerator: 1535.2	mergeSort: 1183.98
#
# quasirandomGenerator
# mergeSort
# 1535.2 1183.98
# 0.287552208263 0.355024777687
# transpose_convfft2d: 	transpose: 1213.84	convfft2d: 4461.87
#
# transpose
# convfft2d
# 1213.84 4461.87
# 0.631724694179 0.136081702492
# scan_MCSingleAsianOptionP: 	scan: 3068.81	MCSingleAsianOptionP: 800.28
#
# scan
# MCSingleAsianOptionP
# 3068.81 800.28
# 0.15770948709 0.617282703151
# reduction_matrixMul: 	reduction: 1449.06	matrixMul: 714.9
#
# reduction
# matrixMul
# 1449.06 714.9
# 0.248748287243 0.483841507711
# matrixMul_binopt: 	matrixMul: 859.73	binopt: 25775.7
#
# matrixMul
# binopt
# 859.73 25775.7
# 0.784449656489 0.0169132441709
# mergeSort_reduction: 	mergeSort: 1135.07	reduction: 1472.8
#
# mergeSort
# reduction
# 1135.07 1472.8
# 0.299048948808 0.269206573539
# sortingNetworks_interval: 	sortingNetworks: 6246.04	interval: 2385.75
#
# sortingNetworks
# interval
# 6246.04 2385.75
# 0.0733798014793 0.15756352468
# binopt_radixSortThrust: 	binopt: 25566.9	radixSortThrust: 3490.95
#
# binopt
# radixSortThrust
# 25566.9 3490.95
# 0.00867558290922 0.0813184158195
# radixSortThrust_mergeSort: 	radixSortThrust: 3557.48	mergeSort: 1122.33
#
# radixSortThrust
# mergeSort
# 3557.48 1122.33
# 0.101926019539 0.284468452797
# transpose_SobolQRNG: 	transpose: 1276.81	SobolQRNG: 1176.46
#
# transpose
# SobolQRNG
# 1276.81 1176.46
# 0.716373168437 0.784678398058
# convfft2d_reduction: 	convfft2d: 4342.53	reduction: 1554.56
#
# convfft2d
# reduction
# 4342.53 1554.56
# 0.10569534198 0.339664428952
# sortingNetworks_radixSortThrust: 	sortingNetworks: 6084.37	radixSortThrust: 3488.44
#
# sortingNetworks
# radixSortThrust
# 6084.37 3488.44
# 0.0455968682119 0.0805409457258
# radixSortThrust_interval: 	radixSortThrust: 3688.86	interval: 2319.88
#
# radixSortThrust
# interval
# 3688.86 2319.88
# 0.142620848588 0.125603466262
# reduction_binopt: 	reduction: 1416	binopt: 25590.3
#
# reduction
# binopt
# 1416.0 25590.3
# 0.22025835696 0.0095987690851
# binopt_sortingNetworks: 	binopt: 25740	sortingNetworks: 6226.87
#
# binopt
# sortingNetworks
# 25740.0 6226.87
# 0.0155047934667 0.0700854436471
# matrixMul_SobolQRNG: 	matrixMul: 827.11	SobolQRNG: 1054.25
#
# matrixMul
# SobolQRNG
# 827.11 1054.25
# 0.716743809544 0.599287014563
# SobolQRNG_mergeSort: 	SobolQRNG: 968.12	mergeSort: 1241.65
#
# SobolQRNG
# mergeSort
# 968.12 1241.65
# 0.468628640777 0.421026128157
# MCSingleAsianOptionP_transpose: 	MCSingleAsianOptionP: 948.01	transpose: 1192.24
#
# MCSingleAsianOptionP
# transpose
# 948.01 1192.24
# 0.91582967888 0.602688533405
# transpose_reduction: 	transpose: 1019.72	reduction: 1481.39
#
# transpose
# reduction
# 1019.72 1481.39
# 0.370775641887 0.276609129532
# convfft2d_quasirandomGenerator: 	convfft2d: 4373.24	quasirandomGenerator: 1637.02
#
# convfft2d
# quasirandomGenerator
# 4373.24 1637.02
# 0.113514724679 0.372947313686
# binopt_MCSingleAsianOptionP: 	binopt: 25801.2	MCSingleAsianOptionP: 953.85
#
# binopt
# MCSingleAsianOptionP
# 25801.2 953.85
# 0.0179192803882 0.927631711901
# binopt_transpose: 	binopt: 25820.1	transpose: 1213.67
#
# binopt
# transpose
# 25820.1 1213.67
# 0.018664930761 0.63149616884
# reduction_interval: 	reduction: 1557	interval: 2286.75
#
# reduction
# interval
# 1557.0 2286.75
# 0.34176713403 0.109528823247
# binopt_interval: 	binopt: 25749.6	interval: 2481.87
#
# binopt
# interval
# 25749.6 2481.87
# 0.0158835365132 0.20420085298
# reduction_mergeSort: 	reduction: 1474.05	mergeSort: 1134.27
#
# reduction
# mergeSort
# 1474.05 1134.27
# 0.270283779009 0.29813337606
# convfft2d_mergeSort: 	convfft2d: 4351.01	mergeSort: 1218.3
#
# convfft2d
# mergeSort
# 4351.01 1218.3
# 0.10785452027 0.394302848576
# scan_convfft2d: 	scan: 3130.83	convfft2d: 4472.72
#
# scan
# convfft2d
# 3130.83 4472.72
# 0.181106550574 0.138844330375
# quasirandomGenerator_reduction: 	quasirandomGenerator: 1541.03	reduction: 1524.27
#
# quasirandomGenerator
# reduction
# 1541.03 1524.27
# 0.292441753191 0.313561585991
# SobolQRNG_quasirandomGenerator: 	SobolQRNG: 1122.5	quasirandomGenerator: 1676.66
#
# SobolQRNG
# quasirandomGenerator
# 1122.5 1676.66
# 0.702821601942 0.406192864451
# sortingNetworks_mergeSort: 	sortingNetworks: 6134.48	mergeSort: 1195.57
#
# sortingNetworks
# mergeSort
# 6134.48 1195.57
# 0.0542082542825 0.368289137874
# MCSingleAsianOptionP_convfft2d: 	MCSingleAsianOptionP: 933.25	convfft2d: 4374.95
#
# MCSingleAsianOptionP
# convfft2d
# 933.25 4374.95
# 0.886001252956 0.113950125018
# transpose_MCSingleAsianOptionP: 	transpose: 1177.9	MCSingleAsianOptionP: 943.12
#
# transpose
# MCSingleAsianOptionP
# 1177.9 943.12
# 0.583411748891 0.90594749712
# matrixMul_radixSortThrust: 	matrixMul: 713.44	radixSortThrust: 3524.82
#
# matrixMul
# radixSortThrust
# 713.44 3524.82
# 0.480811141784 0.0918096158492
# SobolQRNG_matrixMul: 	SobolQRNG: 1044.3	matrixMul: 835.39
#
# SobolQRNG
# matrixMul
# 1044.3 835.39
# 0.584192961165 0.733929720418
# radixSortThrust_matrixMul: 	radixSortThrust: 3511.04	matrixMul: 708.24
#
# radixSortThrust
# matrixMul
# 3511.04 708.24
# 0.0875412740598 0.47001805766
# interval_radixSortThrust: 	interval: 2289.81	radixSortThrust: 3673.78
#
# interval
# radixSortThrust
# 2289.81 3673.78
# 0.1110135322 0.137949833045
# reduction_quasirandomGenerator: 	reduction: 1485.49	quasirandomGenerator: 1512.09
#
# reduction
# quasirandomGenerator
# 1485.49 1512.09
# 0.280142363475 0.268170152809
# transpose_interval: 	transpose: 1375.29	interval: 2590.58
#
# transpose
# interval
# 1375.29 2590.58
# 0.8487565533 0.256946836745
# MCSingleAsianOptionP_radixSortThrust: 	MCSingleAsianOptionP: 721.97	radixSortThrust: 3512.21
#
# MCSingleAsianOptionP
# radixSortThrust
# 721.97 3512.21
# 0.459026332276 0.0879036804381
# SobolQRNG_reduction: 	SobolQRNG: 951.45	reduction: 1530.55
#
# SobolQRNG
# reduction
# 951.45 1530.55
# 0.443340412621 0.318973466275
# SobolQRNG_interval: 	SobolQRNG: 1156.71	interval: 2455.42
#
# SobolQRNG
# interval
# 1156.71 2455.42
# 0.754717839806 0.191367339314
# transpose_binopt: 	transpose: 1200.05	binopt: 25693.8
#
# transpose
# binopt
# 1200.05 25693.8
# 0.613187256352 0.0136820925553
# radixSortThrust_SobolQRNG: 	radixSortThrust: 3607.56	SobolQRNG: 958.2
#
# radixSortThrust
# SobolQRNG
# 3607.56 958.2
# 0.117438251529 0.453580097087
# convfft2d_radixSortThrust: 	convfft2d: 4489.97	radixSortThrust: 3786.65
#
# convfft2d
# radixSortThrust
# 4489.97 3786.65
# 0.143236526778 0.17291120734
# scan_interval: 	scan: 3215.81	interval: 2431.13
#
# scan
# interval
# 3215.81 2431.13
# 0.213165280901 0.179581855498
# radixSortThrust_transpose: 	radixSortThrust: 3577.94	transpose: 1024.67
#
# radixSortThrust
# transpose
# 3577.94 1024.67
# 0.108263484925 0.377429762065
# MCSingleAsianOptionP_binopt: 	MCSingleAsianOptionP: 957.91	binopt: 25761.3
#
# MCSingleAsianOptionP
# binopt
# 957.91 25761.3
# 0.935836549926 0.0163451296011
# mergeSort_SobolQRNG: 	mergeSort: 1284.4	SobolQRNG: 1008.82
#
# mergeSort
# SobolQRNG
# 1284.4 1008.82
# 0.469952046877 0.530370145631
# radixSortThrust_sortingNetworks: 	radixSortThrust: 3493.09	sortingNetworks: 6087.04
#
# radixSortThrust
# sortingNetworks
# 3493.09 6087.04
# 0.0819812787679 0.0460557067832
# MCSingleAsianOptionP_SobolQRNG: 	MCSingleAsianOptionP: 955.76	SobolQRNG: 1127.14
#
# MCSingleAsianOptionP
# SobolQRNG
# 955.76 1127.14
# 0.931491623386 0.709860436893
# radixSortThrust_binopt: 	radixSortThrust: 3488.74	binopt: 25595.7
#
# radixSortThrust
# binopt
# 3488.74 25595.7
# 0.0806338704382 0.00981181204876
# mergeSort_scan: 	mergeSort: 1319.53	scan: 3177
#
# mergeSort
# scan
# 1319.53 3177.0
# 0.510157135173 0.198524196834
# SobolQRNG_scan: 	SobolQRNG: 914.01	scan: 2982.88
#
# SobolQRNG
# scan
# 914.01 2982.88
# 0.386544296117 0.125292368981
# scan_reduction: 	scan: 3085.94	reduction: 1786.34
#
# scan
# reduction
# 3085.94 1786.34
# 0.164171784696 0.53940417611
# interval_convfft2d: 	interval: 2541.34	convfft2d: 4540.97
#
# interval
# convfft2d
# 2541.34 4540.97
# 0.23305563777 0.156222150929
# SobolQRNG_sortingNetworks: 	SobolQRNG: 1071.65	sortingNetworks: 6269.18
#
# SobolQRNG
# sortingNetworks
# 1071.65 6269.18
# 0.625682645631 0.0773564024306
# scan_radixSortThrust: 	scan: 4024.42	radixSortThrust: 4900.98
#
# scan
# radixSortThrust
# 4024.42 4900.98
# 0.518213644389 0.518073856561
# SobolQRNG_radixSortThrust: 	SobolQRNG: 964.76	radixSortThrust: 3623.62
#
# SobolQRNG
# radixSortThrust
# 964.76 3623.62
# 0.463531553398 0.122412821132
# mergeSort_matrixMul: 	mergeSort: 1287.46	matrixMul: 779.13
#
# mergeSort
# matrixMul
# 1287.46 779.13
# 0.473454112638 0.617156852571
# MCSingleAsianOptionP_scan: 	MCSingleAsianOptionP: 798.17	scan: 3066.89
#
# MCSingleAsianOptionP
# scan
# 798.17 3066.89
# 0.613018612453 0.156985166518
# mergeSort_convfft2d: 	mergeSort: 1226.61	convfft2d: 4370.21
#
# mergeSort
# convfft2d
# 1226.61 4370.21
# 0.403813360495 0.112743225833
# interval_reduction: 	interval: 2309.14	reduction: 1560.4
#
# interval
# reduction
# 2309.14 1560.4
# 0.120392428955 0.34469713291
# sortingNetworks_scan: 	sortingNetworks: 6085.29	scan: 2956.37
#
# sortingNetworks
# scan
# 6085.29 2956.37
# 0.0457549698919 0.11529146358
# matrixMul_transpose: 	matrixMul: 815.01	transpose: 1141.27
#
# matrixMul
# transpose
# 815.01 1141.27
# 0.691629133025 0.534171259578
# mergeSort_quasirandomGenerator: 	mergeSort: 1163.35	quasirandomGenerator: 1518.2
#
# mergeSort
# quasirandomGenerator
# 1163.35 1518.2
# 0.331414445449 0.273294530084
# matrixMul_quasirandomGenerator: 	matrixMul: 830.58	quasirandomGenerator: 1615.46
#
# matrixMul
# quasirandomGenerator
# 830.58 1615.46
# 0.723946117603 0.354865223007
# quasirandomGenerator_sortingNetworks: 	quasirandomGenerator: 1579.69	sortingNetworks: 6219.22
#
# quasirandomGenerator
# sortingNetworks
# 1579.69 6219.22
# 0.324865390744 0.0687707938079
# MCSingleAsianOptionP_quasirandomGenerator: 	MCSingleAsianOptionP: 930.44	quasirandomGenerator: 1649
#
# MCSingleAsianOptionP
# quasirandomGenerator
# 930.44 1649.0
# 0.880322535012 0.382994783367
# MCSingleAsianOptionP_mergeSort: 	MCSingleAsianOptionP: 824.56	mergeSort: 1300.37
#
# MCSingleAsianOptionP
# mergeSort
# 824.56 1300.37
# 0.666350059616 0.488229167859
# mergeSort_binopt: 	mergeSort: 1193.67	binopt: 25670.5
#
# mergeSort
# binopt
# 1193.67 25670.5
# 0.366114652597 0.0127628516195
# SobolQRNG_MCSingleAsianOptionP: 	SobolQRNG: 1118.52	MCSingleAsianOptionP: 977.28
#
# SobolQRNG
# MCSingleAsianOptionP
# 1118.52 977.28
# 0.696783980583 0.974981306711
# transpose_mergeSort: 	transpose: 1184.16	mergeSort: 1385.66
#
# transpose
# mergeSort
# 1184.16 1385.66
# 0.591826858449 0.585840667453
# SobolQRNG_convfft2d: 	SobolQRNG: 1104.83	convfft2d: 4444.43
#
# SobolQRNG
# convfft2d
# 1104.83 4444.43
# 0.676016383495 0.131641128273
# convfft2d_binopt: 	convfft2d: 4401.34	binopt: 25844.1
#
# convfft2d
# binopt
# 4401.34 25844.1
# 0.120669548966 0.0196117883773
# MCSingleAsianOptionP_sortingNetworks: 	MCSingleAsianOptionP: 912.59	sortingNetworks: 6252.22
#
# MCSingleAsianOptionP
# sortingNetworks
# 912.59 6252.22
# 0.844249540246 0.0744418323297
# sortingNetworks_reduction: 	sortingNetworks: 6110.11	reduction: 1416.84
#
# sortingNetworks
# reduction
# 6110.11 1416.84
# 0.050020278259 0.220982239036
# matrixMul_interval: 	matrixMul: 856.02	interval: 2491.16
#
# matrixMul
# interval
# 856.02 2491.16
# 0.776749206086 0.20870835173
# binopt_convfft2d: 	binopt: 25965.3	convfft2d: 4424.85
#
# binopt
# convfft2d
# 25965.3 4424.85
# 0.0243934193396 0.126655667079
# scan_transpose: 	scan: 3139.18	transpose: 1164.73
#
# scan
# transpose
# 3139.18 1164.73
# 0.184256590563 0.565707756419
# transpose_scan: 	transpose: 1152.6	scan: 3132.6
#
# transpose
# scan
# 1152.6 3132.6
# 0.549401801317 0.181774283602
# matrixMul_sortingNetworks: 	matrixMul: 815.53	sortingNetworks: 6269.81
#
# matrixMul
# sortingNetworks
# 815.53 6269.81
# 0.692708441437 0.0774646677115
# interval_MCSingleAsianOptionP: 	interval: 2525.94	MCSingleAsianOptionP: 970.09
#
# interval
# MCSingleAsianOptionP
# 2525.94 970.09
# 0.225583573103 0.960451064002
# binopt_scan: 	binopt: 25742.6	scan: 2979.89
#
# binopt
# scan
# 25742.6 2979.89
# 0.0156073697084 0.12416439059
# quasirandomGenerator_interval: 	quasirandomGenerator: 1681.76	interval: 2501.01
#
# quasirandomGenerator
# interval
# 1681.76 2501.01
# 0.410470167905 0.213487561924
# sortingNetworks_SobolQRNG: 	sortingNetworks: 6346.52	SobolQRNG: 1122.89
#
# sortingNetworks
# SobolQRNG
# 6346.52 1122.89
# 0.09064725453 0.703413228155
# quasirandomGenerator_binopt: 	quasirandomGenerator: 1713.5	binopt: 25987
#
# quasirandomGenerator
# binopt
# 1713.5 25987.0
# 0.437090091752 0.0252495364343
# radixSortThrust_convfft2d: 	radixSortThrust: 3856.42	convfft2d: 4578.12
#
# radixSortThrust
# convfft2d
# 3856.42 4578.12
# 0.194522397953 0.165681286952
# transpose_matrixMul: 	transpose: 1203.78	matrixMul: 881.06
#
# transpose
# matrixMul
# 1203.78 881.06
# 0.618201371152 0.828722057328
# convfft2d_matrixMul: 	convfft2d: 4413.12	matrixMul: 879.92
#
# convfft2d
# matrixMul
# 4413.12 879.92
# 0.123668973525 0.826355881193
# transpose_sortingNetworks: 	transpose: 1195.43	sortingNetworks: 6319.38
#
# transpose
# sortingNetworks
# 1195.43 6319.38
# 0.606976744186 0.0859832549699
# scan_quasirandomGenerator: 	scan: 3002.91	quasirandomGenerator: 1524.36
#
# scan
# quasirandomGenerator
# 3002.91 1524.36
# 0.13284869245 0.278460841706
# SobolQRNG_binopt: 	SobolQRNG: 1178.88	binopt: 25939.3
#
# SobolQRNG
# binopt
# 1178.88 25939.3
# 0.788349514563 0.0233676569219
# quasirandomGenerator_scan: 	quasirandomGenerator: 1528.1	scan: 3008.18
#
# quasirandomGenerator
# scan
# 1528.1 3008.18
# 0.281597530906 0.134836801521
# interval_binopt: 	interval: 2569.96	binopt: 25990.5
#
# interval
# binopt
# 2569.96 25990.5
# 0.246942033275 0.0253876198367
# matrixMul_scan: 	matrixMul: 796.19	scan: 3091.46
#
# matrixMul
# scan
# 796.19 3091.46
# 0.652566470869 0.166254206341
# mergeSort_interval: 	mergeSort: 1449.94	interval: 2602.03
#
# mergeSort
# interval
# 1449.94 2602.03
# 0.659406937752 0.262502365345
# interval_mergeSort: 	interval: 2569.13	mergeSort: 1432.1
#
# interval
# mergeSort
# 2569.13 1432.1
# 0.246539318101 0.638989665473
# quasirandomGenerator_transpose: 	quasirandomGenerator: 1697.82	transpose: 1224.26
#
# quasirandomGenerator
# transpose
# 1697.82 1224.26
# 0.42393948035 0.64573195322
# sortingNetworks_MCSingleAsianOptionP: 	sortingNetworks: 6267.6	MCSingleAsianOptionP: 931.68
#
# sortingNetworks
# MCSingleAsianOptionP
# 6267.6 931.68
# 0.0770848799802 0.882828446133
# transpose_radixSortThrust: 	transpose: 1051.14	radixSortThrust: 3621.59
#
# transpose
# radixSortThrust
# 1051.14 3621.59
# 0.41301250168 0.121784030578
# quasirandomGenerator_SobolQRNG: 	quasirandomGenerator: 1720.4	SobolQRNG: 1170.83
#
# quasirandomGenerator
# SobolQRNG
# 1720.4 1170.83
# 0.442877031719 0.776137742718
# reduction_convfft2d: 	reduction: 1623.1	convfft2d: 4471.96
#
# reduction
# convfft2d
# 1623.1 4471.96
# 0.398729759309 0.138650819113
# mergeSort_MCSingleAsianOptionP: 	mergeSort: 1314.89	MCSingleAsianOptionP: 854.58
#
# mergeSort
# MCSingleAsianOptionP
# 1314.89 854.58
# 0.504846813235 0.727017359497
# scan_SobolQRNG: 	scan: 3007.81	SobolQRNG: 951.67
#
# scan
# SobolQRNG
# 3007.81 951.67
# 0.134697218911 0.443674150485
# scan_mergeSort: 	scan: 3210.44	mergeSort: 1373.93
#
# scan
# mergeSort
# 3210.44 1373.93
# 0.2111394468 0.572416082035
# binopt_matrixMul: 	binopt: 25889	matrixMul: 891.21
#
# binopt
# matrixMul
# 25889.0 891.21
# 0.0213832011678 0.8497893273
# MCSingleAsianOptionP_matrixMul: 	MCSingleAsianOptionP: 964.69	matrixMul: 902.74
#
# MCSingleAsianOptionP
# matrixMul
# 964.69 902.74
# 0.949538225249 0.873720915752
# binopt_quasirandomGenerator: 	binopt: 25955	quasirandomGenerator: 1711.84
#
# binopt
# quasirandomGenerator
# 25955.0 1711.84
# 0.0239870596126 0.435697871413
# mergeSort_transpose: 	mergeSort: 1378.71	transpose: 1184.09
#
# mergeSort
# transpose
# 1378.71 1184.09
# 0.577886629204 0.59173275978
# SobolQRNG_transpose: 	SobolQRNG: 1186.6	transpose: 1292.62
#
# SobolQRNG
# transpose
# 1186.6 1292.62
# 0.800060679612 0.737626025003
# quasirandomGenerator_convfft2d: 	quasirandomGenerator: 1662.82	convfft2d: 4418.15
#
# quasirandomGenerator
# convfft2d
# 1662.82 4418.15
# 0.39458543704 0.124949712534
# reduction_radixSortThrust: 	reduction: 1885.32	radixSortThrust: 3896.01
#
# reduction
# radixSortThrust
# 1885.32 3896.01
# 0.624701614085 0.206785362499
# quasirandomGenerator_matrixMul: 	quasirandomGenerator: 1640.03	matrixMul: 858.75
#
# quasirandomGenerator
# matrixMul
# 1640.03 858.75
# 0.37547176141 0.782415575251
# sortingNetworks_quasirandomGenerator: 	sortingNetworks: 6296.81	quasirandomGenerator: 1633.97
#
# sortingNetworks
# quasirandomGenerator
# 6296.81 1633.97
# 0.0821046083203 0.370389318483
# mergeSort_radixSortThrust: 	mergeSort: 1155.29	radixSortThrust: 3602.35
#
# mergeSort
# radixSortThrust
# 1155.29 3602.35
# 0.322190050013 0.115824459023
# scan_matrixMul: 	scan: 3079.19	matrixMul: 789.48
#
# scan
# matrixMul
# 3079.19 789.48
# 0.161625345184 0.638639241163
# transpose_quasirandomGenerator: 	transpose: 1223.79	quasirandomGenerator: 1704.34
#
# transpose
# quasirandomGenerator
# 1223.79 1704.34
# 0.645100147869 0.429407719275
# sortingNetworks_convfft2d: 	sortingNetworks: 6300.16	convfft2d: 4352.81
#
# sortingNetworks
# convfft2d
# 6300.16 4352.81
# 0.0826803046551 0.108312836417
# matrixMul_reduction: 	matrixMul: 743.76	reduction: 1487.36
#
# matrixMul
# reduction
# 743.76 1487.36
# 0.543743124598 0.281753862859
# quasirandomGenerator_radixSortThrust: 	quasirandomGenerator: 1549.32	radixSortThrust: 3610.64
#
# quasirandomGenerator
# radixSortThrust
# 1549.32 3610.64
# 0.299394468021 0.118392278576
# reduction_SobolQRNG: 	reduction: 1559.48	SobolQRNG: 980.45
#
# reduction
# SobolQRNG
# 1559.48 980.45
# 0.343904309684 0.487333131068
# radixSortThrust_quasirandomGenerator: 	radixSortThrust: 3581.83	quasirandomGenerator: 1528.81
#
# radixSortThrust
# quasirandomGenerator
# 3581.83 1528.81
# 0.109468408695 0.282192998641
# convfft2d_sortingNetworks: 	convfft2d: 4339.64	sortingNetworks: 6268.42
#
# convfft2d
# sortingNetworks
# 4339.64 6268.42
# 0.104959489945 0.077225796695
# interval_SobolQRNG: 	interval: 2500.52	SobolQRNG: 1201.98
#
# interval
# SobolQRNG
# 2500.52 1201.98
# 0.213249814411 0.823391990291
# interval_scan: 	interval: 2519.55	scan: 3267.91
#
# interval
# scan
# 2519.55 3267.91
# 0.222483151465 0.232820021428
# sortingNetworks_binopt: 	sortingNetworks: 6313.45	binopt: 25934.7
#
# sortingNetworks
# binopt
# 6313.45 25934.7
# 0.0849641865325 0.0231861758788
# binopt_SobolQRNG: 	binopt: 26025	SobolQRNG: 1183.64
#
# binopt
# SobolQRNG
# 26025.0 1183.64
# 0.0267487276601 0.79557038835
# convfft2d_transpose: 	convfft2d: 4546.48	transpose: 1277.84
#
# convfft2d
# transpose
# 4546.48 1277.84
# 0.157625107577 0.71775776314
# convfft2d_SobolQRNG: 	convfft2d: 4552.1	SobolQRNG: 1187.74
#
# convfft2d
# SobolQRNG
# 4552.1 1187.74
# 0.159056072434 0.801790048544
# interval_matrixMul: 	interval: 2421.76	matrixMul: 868.73
#
# interval
# matrixMul
# 2421.76 868.73
# 0.175035540827 0.803129994396
# mergeSort_sortingNetworks: 	mergeSort: 1246.26	sortingNetworks: 6224.71
#
# mergeSort
# sortingNetworks
# 1246.26 6224.71
# 0.426302116118 0.0697142483984
# radixSortThrust_MCSingleAsianOptionP: 	radixSortThrust: 3546.37	MCSingleAsianOptionP: 757.42
#
# radixSortThrust
# MCSingleAsianOptionP
# 3546.37 757.42
# 0.0984847076898 0.530667097791
# reduction_sortingNetworks: 	reduction: 1439.25	sortingNetworks: 6140.55
#
# reduction
# sortingNetworks
# 1439.25 6140.55
# 0.240294378711 0.0552513816712
# MCSingleAsianOptionP_interval: 	MCSingleAsianOptionP: 980.31	interval: 2538.05
#
# MCSingleAsianOptionP
# interval
# 980.31 2538.05
# 0.981104621789 0.231459333045
# reduction_MCSingleAsianOptionP: 	reduction: 1488.43	MCSingleAsianOptionP: 767.72
#
# reduction
# MCSingleAsianOptionP
# 1488.43 767.72
# 0.282675950742 0.551482327264
# scan_binopt: 	scan: 3005.5	binopt: 25815.4
#
# scan
# binopt
# 3005.5 25815.4
# 0.133825770722 0.0184795044778
# matrixMul_MCSingleAsianOptionP: 	matrixMul: 923.93	MCSingleAsianOptionP: 990.36
#
# matrixMul
# MCSingleAsianOptionP
# 923.93 990.36
# 0.917702733556 1.00141462725
# sortingNetworks_transpose: 	sortingNetworks: 6290.53	transpose: 1185.57
#
# sortingNetworks
# transpose
# 6290.53 1185.57
# 0.0810253925046 0.593722274499
# MCSingleAsianOptionP_reduction: 	MCSingleAsianOptionP: 744.31	reduction: 1461.52
#
# MCSingleAsianOptionP
# reduction
# 744.31 1461.52
# 0.504173150375 0.259485871373
# scan_sortingNetworks: 	scan: 3002.31	sortingNetworks: 6140.41
#
# scan
# sortingNetworks
# 3002.31 6140.41
# 0.132622342272 0.0552273227199
# interval_quasirandomGenerator: 	interval: 2486.31	quasirandomGenerator: 1696.28
#
# interval
# quasirandomGenerator
# 2486.31 1696.28
# 0.206355136559 0.422647902444
# quasirandomGenerator_MCSingleAsianOptionP: 	quasirandomGenerator: 1696.07	MCSingleAsianOptionP: 977.32
#
# quasirandomGenerator
# MCSingleAsianOptionP
# 1696.07 977.32
# 0.422471778184 0.975062142554
# reduction_transpose: 	reduction: 1525.5	transpose: 1055.77
#
# reduction
# transpose
# 1525.5 1055.77
# 0.314621556174 0.419236456513
# matrixMul_convfft2d: 	matrixMul: 872.02	convfft2d: 4420.6
#
# matrixMul
# convfft2d
# 872.02 4420.6
# 0.809958695697 0.125573531733
# matrixMul_mergeSort: 	matrixMul: 843.57	mergeSort: 1367.29
#
# matrixMul
# mergeSort
# 843.57 1367.29
# 0.750908071982 0.564816828227
# sortingNetworks_matrixMul: 	sortingNetworks: 6322.19	matrixMul: 853.98
#
# sortingNetworks
# matrixMul
# 6322.19 853.98
# 0.0864661524925 0.77251499616
# interval_sortingNetworks: 	interval: 2430.61	sortingNetworks: 6324.81
#
# interval
# sortingNetworks
# 2430.61 6324.81
# 0.179329552016 0.0869163985812
# interval_transpose: 	interval: 2640.08	transpose: 1433.41
#
# interval
# transpose
# 2640.08 1433.41
# 0.280964187461 0.92688533405
# convfft2d_scan: 	convfft2d: 4548.08	scan: 3182.05
#
# convfft2d
# scan
# 4548.08 3182.05
# 0.158032499707 0.200429310839
# binopt_mergeSort: 	binopt: 25835.9	mergeSort: 1239.37
#
# binopt
# mergeSort
# 25835.9 1239.37
# 0.0192882786918 0.418416745826

# %% [markdown]
# ### mergeSort

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['mergeSort']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['mergeSort', 0.2990489488080388, 'reduction', 0.26920657353866284]
# 0.284127761173
# ['mergeSort', 0.46995204687732484, 'SobolQRNG', 0.5303701456310679]
# 0.500161096254
# ['mergeSort', 0.5101571351728715, 'scan', 0.19852419683411537]
# 0.354340666003
# ['mergeSort', 0.47345411263833737, 'matrixMul', 0.6171568525706219]
# 0.545305482604
# ['mergeSort', 0.4038133604953247, 'convfft2d', 0.112743225832735]
# 0.258278293164
# ['mergeSort', 0.3314144454490311, 'quasirandomGenerator', 0.2732945300837011]
# 0.302354487766
# ['mergeSort', 0.36611465259736553, 'binopt', 0.012762851619521065]
# 0.189438752108
# ['mergeSort', 0.6594069377524978, 'interval', 0.26250236534514637]
# 0.460954651549
# ['mergeSort', 0.5048468132346042, 'MCSingleAsianOptionP', 0.7270173594972011]
# 0.615932086366
# ['mergeSort', 0.5778866292044817, 'transpose', 0.5917327597795401]
# 0.584809694492
# ['mergeSort', 0.32219005001316137, 'radixSortThrust', 0.1158244590232993]
# 0.219007254518
# ['mergeSort', 0.4263021161175138, 'sortingNetworks', 0.06971424839836127]
# 0.248008182258
#
# --------
#
# mergeSort+binopt
# ['mergeSort', 0.36611465259736553, 'binopt', 0.012762851619521065]

# %% [markdown]
# ### radixSortThrust

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['radixSortThrust']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['radixSortThrust', 0.5130063622453087, 'scan', 0.5109666661636663]
# 0.511986514204
# ['radixSortThrust', 0.19473922228210694, 'reduction', 0.6060357976921951]
# 0.400387509987
# ['radixSortThrust', 0.10192601953896951, 'mergeSort', 0.28446845279650246]
# 0.193197236168
# ['radixSortThrust', 0.14262084858847368, 'interval', 0.12560346626168717]
# 0.134112157425
# ['radixSortThrust', 0.08754127405975676, 'matrixMul', 0.4700180576599764]
# 0.27877966586
# ['radixSortThrust', 0.11743825152861143, 'SobolQRNG', 0.4535800970873787]
# 0.285509174308
# ['radixSortThrust', 0.1082634849245141, 'transpose', 0.37742976206479373]
# 0.242846623495
# ['radixSortThrust', 0.08198127876794215, 'sortingNetworks', 0.04605570678324944]
# 0.0640184927756
# ['radixSortThrust', 0.08063387043817083, 'binopt', 0.009811812048763136]
# 0.0452228412435
# ['radixSortThrust', 0.19452239795317827, 'convfft2d', 0.16568128695173923]
# 0.180101842452
# ['radixSortThrust', 0.10946840869527508, 'quasirandomGenerator', 0.2821929986413272]
# 0.195830703668
# ['radixSortThrust', 0.09848470768982964, 'MCSingleAsianOptionP', 0.5306670977911605]
# 0.31457590274
#
# --------
#
# radixSortThrust+binopt
# ['radixSortThrust', 0.08063387043817083, 'binopt', 0.009811812048763136]

# %% [markdown]
# ### scan

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['scan']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['scan', 0.1577094870904947, 'MCSingleAsianOptionP', 0.617282703150577]
# 0.387496095121
# ['scan', 0.1811065505741749, 'convfft2d', 0.13884433037464805]
# 0.159975440474
# ['scan', 0.21316528090057174, 'interval', 0.1795818554980324]
# 0.196373568199
# ['scan', 0.1641717846957098, 'reduction', 0.5394041761101678]
# 0.351787980403
# ['scan', 0.518213644388779, 'radixSortThrust', 0.5180738565614138]
# 0.518143750475
# ['scan', 0.1842565905627065, 'transpose', 0.5657077564188735]
# 0.374982173491
# ['scan', 0.13284869245046682, 'quasirandomGenerator', 0.27846084170622465]
# 0.205654767078
# ['scan', 0.13469721891080289, 'SobolQRNG', 0.4436741504854367]
# 0.289185684698
# ['scan', 0.21113944680016283, 'mergeSort', 0.5724160820353184]
# 0.391777764418
# ['scan', 0.1616253451840226, 'matrixMul', 0.6386392411631623]
# 0.400132293174
# ['scan', 0.13382577072235868, 'binopt', 0.01847950447784763]
# 0.0761526376001
# ['scan', 0.13262234227165037, 'sortingNetworks', 0.05522732271989872]
# 0.0939248324958
#
# --------
#
# scan+binopt
# ['scan', 0.13382577072235868, 'binopt', 0.01847950447784763]

# %% [markdown]
# ### SobolQRNG

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['SobolQRNG']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['SobolQRNG', 0.46862864077669886, 'mergeSort', 0.42102612815729556]
# 0.444827384467
# ['SobolQRNG', 0.7028216019417475, 'quasirandomGenerator', 0.406192864451415]
# 0.554507233197
# ['SobolQRNG', 0.5841929611650483, 'matrixMul', 0.7339297204176092]
# 0.659061340791
# ['SobolQRNG', 0.44334041262135915, 'reduction', 0.3189734662748509]
# 0.381156939448
# ['SobolQRNG', 0.7547178398058252, 'interval', 0.19136733931421968]
# 0.47304258956
# ['SobolQRNG', 0.38654429611650465, 'scan', 0.1252923689809715]
# 0.255918332549
# ['SobolQRNG', 0.625682645631068, 'sortingNetworks', 0.07735640243064146]
# 0.351519524031
# ['SobolQRNG', 0.4635315533980582, 'radixSortThrust', 0.12241282113231855]
# 0.292972187265
# ['SobolQRNG', 0.6967839805825242, 'MCSingleAsianOptionP', 0.9749813067113959]
# 0.835882643647
# ['SobolQRNG', 0.6760163834951454, 'convfft2d', 0.13164112827250474]
# 0.403828755884
# ['SobolQRNG', 0.7883495145631068, 'binopt', 0.023367656921923663]
# 0.405858585743
# ['SobolQRNG', 0.8000606796116503, 'transpose', 0.7376260250033606]
# 0.768843352308
#
# --------
#
# SobolQRNG+scan
# ['SobolQRNG', 0.38654429611650465, 'scan', 0.1252923689809715]

# %% [markdown]
# ### transpose

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['transpose']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['transpose', 0.6317246941793251, 'convfft2d', 0.13608170249171203]
# 0.383903198336
# ['transpose', 0.7163731684366179, 'SobolQRNG', 0.7846783980582523]
# 0.750525783247
# ['transpose', 0.37077564188735046, 'reduction', 0.2766091295318034]
# 0.32369238571
# ['transpose', 0.5834117488909802, 'MCSingleAsianOptionP', 0.9059474971202233]
# 0.744679623006
# ['transpose', 0.8487565533001749, 'interval', 0.2569468367450909]
# 0.552851695023
# ['transpose', 0.61318725635166, 'binopt', 0.013682092555332037]
# 0.313434674453
# ['transpose', 0.5918268584487163, 'mergeSort', 0.5858406674525334]
# 0.588833762951
# ['transpose', 0.5494018013173814, 'scan', 0.18177428360168402]
# 0.36558804246
# ['transpose', 0.6182013711520367, 'matrixMul', 0.8287220573278813]
# 0.72346171424
# ['transpose', 0.6069767441860467, 'sortingNetworks', 0.08598325496989201]
# 0.346479999578
# ['transpose', 0.41301250168033365, 'radixSortThrust', 0.12178403057842546]
# 0.267398266129
# ['transpose', 0.6451001478693372, 'quasirandomGenerator', 0.42940771927470345]
# 0.537253933572
#
# --------
#
# transpose+radixSortThrust
# ['transpose', 0.41301250168033365, 'radixSortThrust', 0.12178403057842546]

# %% [markdown]
# ### interval

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['interval']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['interval', 0.11101353220023169, 'radixSortThrust', 0.13794983304526687]
# 0.124481682623
# ['interval', 0.23305563776983118, 'convfft2d', 0.15622215092859948]
# 0.194638894349
# ['interval', 0.12039242895473556, 'reduction', 0.34469713290991977]
# 0.232544780932
# ['interval', 0.22558357310250798, 'MCSingleAsianOptionP', 0.9604510640017785]
# 0.593017318552
# ['interval', 0.24694203327494768, 'binopt', 0.025387619836667152]
# 0.136164826556
# ['interval', 0.24653931810131913, 'mergeSort', 0.638989665472607]
# 0.442764491787
# ['interval', 0.2132498144113808, 'SobolQRNG', 0.8233919902912621]
# 0.518320902351
# ['interval', 0.2224831514645731, 'scan', 0.23282002142781688]
# 0.227651586446
# ['interval', 0.1750355408270703, 'matrixMul', 0.8031299943958985]
# 0.489082767611
# ['interval', 0.20635513655925952, 'quasirandomGenerator', 0.4226479024439338]
# 0.314501519502
# ['interval', 0.17932955201575917, 'sortingNetworks', 0.08691639858120936]
# 0.133122975298
# ['interval', 0.2809641874614872, 'transpose', 0.9268853340502758]
# 0.603924760756
#
# --------
#
# interval+radixSortThrust
# ['interval', 0.11101353220023169, 'radixSortThrust', 0.13794983304526687]

# %% [markdown]
# ### binomialOptions

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['binopt']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['binopt', 0.010265514656566888, 'reduction', 0.21728526986151442]
# 0.113775392259
# ['binopt', 0.008675582909219992, 'radixSortThrust', 0.08131841581950305]
# 0.0449969993644
# ['binopt', 0.015504793466682543, 'sortingNetworks', 0.07008544364706215]
# 0.0427951185569
# ['binopt', 0.017919280388211556, 'MCSingleAsianOptionP', 0.9276317119010571]
# 0.472775496145
# ['binopt', 0.018664930761036702, 'transpose', 0.6314961688398979]
# 0.3250805498
# ['binopt', 0.01588353651319685, 'interval', 0.20420085297984958]
# 0.110042194747
# ['binopt', 0.024393419339566735, 'convfft2d', 0.1266556670791512]
# 0.0755245432094
# ['binopt', 0.015607369708446672, 'scan', 0.12416439058986839]
# 0.0698858801492
# ['binopt', 0.02138320116779102, 'matrixMul', 0.8497893273002761]
# 0.435586264234
# ['binopt', 0.02398705961257752, 'quasirandomGenerator', 0.4356978714125166]
# 0.229842465513
# ['binopt', 0.026748727660078186, 'SobolQRNG', 0.7955703883495147]
# 0.411159558005
# ['binopt', 0.01928827869175853, 'mergeSort', 0.4184167458255603]
# 0.218852512259
#
# --------
#
# binopt+sortingNetworks
# ['binopt', 0.015504793466682543, 'sortingNetworks', 0.07008544364706215]

# %% [markdown]
# ### matrixMul

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['matrixMul']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['matrixMul', 0.7844496564893417, 'binopt', 0.016913244170907893]
# 0.40068145033
# ['matrixMul', 0.716743809543577, 'SobolQRNG', 0.5992870145631066]
# 0.658015412053
# ['matrixMul', 0.48081114178376483, 'radixSortThrust', 0.09180961584923897]
# 0.286310378817
# ['matrixMul', 0.6916291330247617, 'transpose', 0.5341712595779002]
# 0.612900196301
# ['matrixMul', 0.723946117603105, 'quasirandomGenerator', 0.3548652230068605]
# 0.539405670305
# ['matrixMul', 0.7767492060856389, 'interval', 0.20870835173046198]
# 0.492728778908
# ['matrixMul', 0.6927084414371405, 'sortingNetworks', 0.07746466771151272]
# 0.385086554574
# ['matrixMul', 0.6525664708690508, 'scan', 0.166254206340823]
# 0.409410338605
# ['matrixMul', 0.5437431245978537, 'reduction', 0.281753862858817]
# 0.412748493728
# ['matrixMul', 0.9177027335561134, 'MCSingleAsianOptionP', 1.0014146272457207]
# 0.959558680401
# ['matrixMul', 0.8099586956972953, 'convfft2d', 0.12557353173330088]
# 0.467766113715
# ['matrixMul', 0.7509080719815688, 'mergeSort', 0.5648168282271078]
# 0.657862450104
#
# --------
#
# matrixMul+radixSortThrust
# ['matrixMul', 0.48081114178376483, 'radixSortThrust', 0.09180961584923897]

# %% [markdown]
# ### quasirandomGenerator

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['quasirandomGenerator']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['quasirandomGenerator', 0.28755220826274397, 'mergeSort', 0.3550247776874922]
# 0.321288492975
# ['quasirandomGenerator', 0.292441753191204, 'reduction', 0.31356158599115824]
# 0.303001669591
# ['quasirandomGenerator', 0.3248653907442509, 'sortingNetworks', 0.0687707938079134]
# 0.196818092276
# ['quasirandomGenerator', 0.4104701679051279, 'interval', 0.2134875619235228]
# 0.311978864914
# ['quasirandomGenerator', 0.4370900917523526, 'binopt', 0.025249536434291953]
# 0.231169814093
# ['quasirandomGenerator', 0.28159753090561424, 'scan', 0.13483680152107302]
# 0.208217166213
# ['quasirandomGenerator', 0.42393948034956486, 'transpose', 0.6457319532195187]
# 0.534835716785
# ['quasirandomGenerator', 0.4428770317191406, 'SobolQRNG', 0.7761377427184464]
# 0.609507387219
# ['quasirandomGenerator', 0.39458543703977056, 'convfft2d', 0.12494971253392806]
# 0.259767574787
# ['quasirandomGenerator', 0.375471761410336, 'matrixMul', 0.7824155752506279]
# 0.57894366833
# ['quasirandomGenerator', 0.29939446802086667, 'radixSortThrust', 0.11839227857589774]
# 0.208893373298
# ['quasirandomGenerator', 0.422471778184075, 'MCSingleAsianOptionP', 0.9750621425540087]
# 0.698766960369
#
# --------
#
# quasirandomGenerator+sortingNetworks
# ['quasirandomGenerator', 0.3248653907442509, 'sortingNetworks', 0.0687707938079134]

# %% [markdown]
# ### reduction

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['reduction']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['reduction', 0.5136115683249884, 'scan', 0.15888273551736098]
# 0.336247151921
# ['reduction', 0.24874828724330178, 'matrixMul', 0.48384150771082823]
# 0.366294897477
# ['reduction', 0.22025835696003981, 'binopt', 0.009598769085098713]
# 0.114928563023
# ['reduction', 0.3417671340302133, 'interval', 0.10952882324685453]
# 0.225647978639
# ['reduction', 0.27028377900914324, 'mergeSort', 0.2981333760600615]
# 0.284208577535
# ['reduction', 0.2801423634749787, 'quasirandomGenerator', 0.26817015280876255]
# 0.274156258142
# ['reduction', 0.3987297593092094, 'convfft2d', 0.13865081911280175]
# 0.268690289211
# ['reduction', 0.6247016140846768, 'radixSortThrust', 0.20678536249930302]
# 0.415743488292
# ['reduction', 0.34390430968364627, 'SobolQRNG', 0.48733313106796117]
# 0.415618720376
# ['reduction', 0.2402943787109728, 'sortingNetworks', 0.05525138167120347]
# 0.147772880191
# ['reduction', 0.28267595074154817, 'MCSingleAsianOptionP', 0.5514823272639089]
# 0.417079139003
# ['reduction', 0.3146215561741108, 'transpose', 0.41923645651297226]
# 0.366929006344
#
# --------
#
# reduction+binopt
# ['reduction', 0.22025835696003981, 'binopt', 0.009598769085098713]

# %% [markdown]
# ### convfft2d

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['convfft2d']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['convfft2d', 0.16136293037159244, 'interval', 0.24441899845221515]
# 0.202890964412
# ['convfft2d', 0.11394503261683253, 'MCSingleAsianOptionP', 0.8703190994887133]
# 0.492132066053
# ['convfft2d', 0.10569534198023112, 'reduction', 0.3396644289518358]
# 0.222679885466
# ['convfft2d', 0.11351472467930601, 'quasirandomGenerator', 0.3729473136856938]
# 0.243231019182
# ['convfft2d', 0.10785452027030473, 'mergeSort', 0.3943028485757121]
# 0.251078684423
# ['convfft2d', 0.14323652677839394, 'radixSortThrust', 0.17291120733981336]
# 0.158073867059
# ['convfft2d', 0.12066954896598792, 'binopt', 0.019611788377322803]
# 0.0701406686717
# ['convfft2d', 0.12366897352460393, 'matrixMul', 0.8263558811930507]
# 0.475012427359
# ['convfft2d', 0.104959489945053, 'sortingNetworks', 0.07722579669498741]
# 0.09109264332
# ['convfft2d', 0.15762510757698434, 'transpose', 0.717757763140207]
# 0.437691435359
# ['convfft2d', 0.15905607243432085, 'SobolQRNG', 0.8017900485436893]
# 0.480423060489
# ['convfft2d', 0.1580324997071869, 'scan', 0.2004293108391555]
# 0.179230905273
#
# --------
#
# convfft2d+binopt
# ['convfft2d', 0.12066954896598792, 'binopt', 0.019611788377322803]

# %% [markdown]
# ### MCSingleAsianOptionP

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['MCSingleAsianOptionP']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['MCSingleAsianOptionP', 0.9158296788796152, 'transpose', 0.6026885334050276]
# 0.759259106142
# ['MCSingleAsianOptionP', 0.8860012529555605, 'convfft2d', 0.1139501250184598]
# 0.499975688987
# ['MCSingleAsianOptionP', 0.4590263322757311, 'radixSortThrust', 0.08790368043810903]
# 0.273465006357
# ['MCSingleAsianOptionP', 0.9358365499262373, 'binopt', 0.0163451296011361]
# 0.476090839764
# ['MCSingleAsianOptionP', 0.9314916233858093, 'SobolQRNG', 0.709860436893204]
# 0.82067603014
# ['MCSingleAsianOptionP', 0.6130186124527615, 'scan', 0.15698516651828132]
# 0.385001889486
# ['MCSingleAsianOptionP', 0.8803225350120245, 'quasirandomGenerator', 0.38299478336716053]
# 0.63165865919
# ['MCSingleAsianOptionP', 0.6663500596164338, 'mergeSort', 0.48822916785881865]
# 0.577289613738
# ['MCSingleAsianOptionP', 0.8442495402461452, 'sortingNetworks', 0.07444183232973134]
# 0.459345686288
# ['MCSingleAsianOptionP', 0.9495382252490756, 'matrixMul', 0.8737209157516759]
# 0.9116295705
# ['MCSingleAsianOptionP', 0.9811046217893014, 'interval', 0.23145933304544863]
# 0.606281977417
# ['MCSingleAsianOptionP', 0.5041731503748761, 'reduction', 0.259485871373049]
# 0.381829510874
#
# --------
#
# MCSingleAsianOptionP+radixSortThrust
# ['MCSingleAsianOptionP', 0.4590263322757311, 'radixSortThrust', 0.08790368043810903]

# %% [markdown]
# ### sortingNetworks

# %%
MAXslowdown = 1
best_combo = None
best_combo_result = None

for dd in result_dlist['sortingNetworks']:
    # for each combination, compute the avg slowdown
    for key, value in dd.iteritems():
        print value
        avg_slowdown = ( float(value[1]) + float(value[3]) ) * 0.5
        print avg_slowdown
    
        if avg_slowdown < MAXslowdown:
            best_combo = key
            best_combo_result = value
            MAXslowdown = avg_slowdown
            


print "\n--------\n"
print best_combo
print best_combo_result
# Out:
# ['sortingNetworks', 0.07337980147928191, 'interval', 0.15756352467964718]
# 0.115471663079
# ['sortingNetworks', 0.04559686821193876, 'radixSortThrust', 0.08054094572577286]
# 0.0630689069689
# ['sortingNetworks', 0.05420825428249332, 'mergeSort', 0.3682891378738111]
# 0.211248696078
# ['sortingNetworks', 0.04575496989194083, 'scan', 0.11529146358025599]
# 0.0805232167361
# ['sortingNetworks', 0.05002027825895672, 'reduction', 0.22098223903620262]
# 0.135501258648
# ['sortingNetworks', 0.09064725452995681, 'SobolQRNG', 0.7034132281553398]
# 0.397030241343
# ['sortingNetworks', 0.07708487998020308, 'MCSingleAsianOptionP', 0.8828284461330154]
# 0.479956663057
# ['sortingNetworks', 0.08210460832027278, 'quasirandomGenerator', 0.3703893184829832]
# 0.226246963402
# ['sortingNetworks', 0.08268030465506326, 'convfft2d', 0.10831283641678269]
# 0.0954965705359
# ['sortingNetworks', 0.08496418653248639, 'binopt', 0.02318617587880234]
# 0.0540751812056
# ['sortingNetworks', 0.08102539250460561, 'transpose', 0.5937222744992605]
# 0.337373833502
# ['sortingNetworks', 0.08646615249250722, 'matrixMul', 0.7725149961601527]
# 0.429490574326
#
# --------
#
# sortingNetworks+binopt
# ['sortingNetworks', 0.08496418653248639, 'binopt', 0.02318617587880234]
