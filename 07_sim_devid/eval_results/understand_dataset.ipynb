1.7377378941,
1.7065291405,
1.8029389381,
1.4946579933,
2.4232428074,
1.445335865,
1.4851429462,
1.4266450405,
3.8601200581,
26.1826109886,
0.575357914,
1.6683228016,
0.561964035,
1.9187650681,
0.6316258907,
2.7364230156,
1.5934159756,
2.0259251595,
1.8997249603,
1.4040088654,
56.3069639206,
1.7048490048,
0.623210907,
0.4620370865,
0.6153628826,
0.5767409801,
29.0600039959,
0.6980609894,
2.6613481045,
0.8711819649,
0.4997730255,
0.7912380695,
1.8876309395,
2.5010371208,
1.942250967,
1.9741139412,
1.4287919998,
1.6790020466,
3.4120180607,
1.7167730331,
1.6085150242,
2.2580740452,
1.7840380669,
4.7146937847,
4.8620209694,
1.3941099644,
1.4420349598,
1.4089820385,
1.5153009892,
1.6408109665,
1.4830198288,
1.6538870335,
4.29626894,
1.5513970852,
2.4569540024,
2.5289590359,
1.5727610588,
1.4841549397,
2.656015873,
4.1693520546,
15.2093601227,
0.8075780869,
0.5128951073,
1.5144891739,
6.2066590786,
28.6789529324,
0.4917550087,
0.4812772274,
0.4983811378,
0.7522189617,
31.0251638889,
6.3362438679,
0.5515010357,
0.8471438885,
0.5473878384,
3.3195149899,
0.4835889339,
23.328207016    
]

# %%
def analyze_data(app_singleExe_time_seq):
    tot = len(app_singleExe_time_seq)
    count1 = 0
    count2 = 0
    count3 = 0
    count4 = 0
    count5 = 0
    for v in app_singleExe_time_seq:
        if v<1.0:
            count1 = count1 + 1
        if v>= 1.0 and v<2.0:
            count2 = count2 + 1
        if v>= 2.0 and v<5.0:
            count3 = count3 + 1
        if v>=5.0 and v < 10:
            count4 =  count4 + 1
        if v>=10.0:
            count5 =  count5 + 1

    print("0-1: {} {}\n1-2: {} {}\n2-5: {} {}\n5-10: {} {}\n>10: {} {}\n".format(count1, float(count1) / tot,
                                                         count2, float(count2) / tot,
                                                         count3, float(count3) / tot,
                                                         count4, float(count4) / tot,
                                                         count5, float(count5) / tot))

# %%
analyze_data(app_singleExe_time_seq1)
# Out:
# 0-1: 10 0.126582278481
# 1-2: 45 0.569620253165
# 2-5: 15 0.189873417722
# 5-10: 2 0.0253164556962
# >10: 7 0.0886075949367

# %%
analyze_data(app_singleExe_time_seq2)
# Out:
# 0-1: 19 0.240506329114
# 1-2: 34 0.430379746835
# 2-5: 17 0.215189873418
# 5-10: 2 0.0253164556962
# >10: 7 0.0886075949367

# %%
analyze_data(app_singleExe_time_seq3)
# Out:
# 0-1: 21 0.26582278481
# 1-2: 33 0.417721518987
# 2-5: 16 0.20253164557
# 5-10: 2 0.0253164556962
# >10: 7 0.0886075949367
