# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# %matplotlib inline

# %%
#
# plot
#
def genPlot(similarity, avg_speedup, labels, myTitle):
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots()
    
    idx = [ 2*i+1 for i in xrange(len(labels))]

    ax.plot(idx, similarity, marker='^', markersize = 13, label='Similarity')
    ax.plot(idx, avg_speedup, marker='o', markersize = 13, linestyle='--', color='r', label='AvgSpeedup')

    ax.set_xticks([1, 3, 5])
    ax.set_xticklabels(labels)

    ax.set_xlim((0, 6))

    plt.xlabel(myTitle, fontsize=15, labelpad=10)  # add space between xlabel and xticklabel

    leg = ax.legend(
        ncol=2, 
        scatterpoints=1,
        labelspacing=1,
        loc='upper center',
        bbox_to_anchor=(0, 1.1, 1., 0.05),
        fontsize =13)

    leg.get_frame().set_alpha(1)
    leg.get_frame().set_linewidth(1)
    leg.get_frame().set_edgecolor("k")

    # We change the fontsize of minor ticks label 
    plt.tick_params(axis='both', which='major', labelsize=13)
    plt.tight_layout()
    plt.show()

    ### output
    fig.savefig(myTitle + '.pdf',  transparent = True, bbox_inches='tight')
    fig.savefig(myTitle + '.png',  dpi=300, transparent = True, bbox_inches='tight')

# %% [markdown]
# ### MC_SiglAsnOptP

# %%
myTitle='MC_SiglAsnOptP'

similarity=np.array([0.388, 0.571, 0.697])
avg_speedup=np.array([0.9543718269, 1.255099298,  1.376521764])
labels = ['interval', 'binopt', 'reduction']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### SobolQRNG

# %%
myTitle='SobolQRNG'

similarity=np.array([0.406, 0.511, 0.512])

avg_speedup=np.array([0.871, 0.837,  0.829])

labels = ['binopt', 'interval', 'reduction']


genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### sortingNetworks

# %%
myTitle='sortingNetworks'

similarity=np.array([0.496, 0.55, 0.642])

avg_speedup=np.array([0.951, 1.,  0.923])

labels = ['interval', 'binopt', 'reduction']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### radixSortThrust

# %%
myTitle='radixSortThrust'

similarity=np.array([0.425, 0.494, 0.663])

avg_speedup=np.array([1.006, 0.955,  0.894])

labels = ['binopt', 'interval', 'quasirandGen']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### reduction

# %%
myTitle='reduction'
similarity=np.array([0.411, 0.458, 0.486])
avg_speedup=np.array([0.915, 0.833,  0.846])
labels = ['binopt',  'quasirandGen', 'interval']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### interval

# %%
myTitle='interval'
similarity=np.array([0.268, 0.367, 0.388])
avg_speedup=np.array([0.985, 0.774,  0.876])
labels = ['binopt',  'quasirandGen', 'MC_SiglAsnOptP']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### quasirandomGenerator

# %%
myTitle='quasirandomGenerator'
similarity=np.array([0.3668745727, 0.457934699, 0.6551443722])
avg_speedup=np.array([0.870, 0.832,  0.774])
labels = ['interval',  'reduction', 'matrixMul']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### mergeSort

# %%
myTitle='mergeSort'
similarity=np.array([0.4703308592, 0.6635686353, 0.6856430957])
avg_speedup=np.array([0.799, 0.827,  0.773])
labels = ['interval',  'binopt', 'reduction']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### matrixMul

# %%
myTitle='matrixMul'
similarity=np.array([0.2867090806, 0.3158646394, 0.4166084123])
avg_speedup=np.array([0.9057212463, 1.076214034,  1.080234808])
labels = ['reduction',  'quasirandGen', 'scan']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### binopt (tbc)

# %%
myTitle='binopt'
similarity=np.array([0.1520763314, 0.2570143772, 0.4686465312])
avg_speedup=np.array([0.9560108044, 0.9213135363,  0.9988257828])
labels = ['interval',  'reduction', 'radixSortThrust']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### scan

# %%
myTitle='scan'
similarity=np.array([0.1770608118, 0.4166084123, 0.4811764806])
avg_speedup=np.array([0.824766961, 0.8438595329,  1.051355745])
labels = ['interval',  'matrixMul', 'binopt']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### transpose

# %%
myTitle='transpose'
similarity=np.array([0.2072869035, 0.5308244326, 0.6463528187])
avg_speedup=np.array([0.7644694918, 0.8404025289,  0.9345376809])
labels = ['interval',  'matrixMul', 'binopt']

genPlot(similarity, avg_speedup, labels, myTitle)

# %% [markdown]
# ### convolutionFFT2D

# %%
myTitle='convolutionFFT2D'
similarity=np.array([0.4217767659, 0.5226965622, 0.528201802])
avg_speedup=np.array([0.9001249759, 0.9959241182,  0.9250310561])
labels = ['interval',  'binopt', 'matrixMul']

genPlot(similarity, avg_speedup, labels, myTitle)

# %%
## blank



### output
#fig.savefig(myTitle + '.pdf',  transparent = True, bbox_inches='tight')
#fig.savefig(myTitle + '.png',  dpi=300, transparent = True, bbox_inches='tight')
