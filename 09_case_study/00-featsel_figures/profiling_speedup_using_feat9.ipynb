# %%
#%matplotlib inline
# %matplotlib notebook

import matplotlib as mpl
mpl.__version__

import numpy as np
import matplotlib.pyplot as plt

# %%
figname = "feat9_profile_speedup"
# title="Feat9 Profling Overhead"
ylabel= 'Speedup Over FeatAll'

xlabs = ['sdk_binomOptions',
'parboil_lbm',
'poly_2dconv',
'rodinia_hotspot']


y = [
1.133487539,
1.508085446,
2.139741519,
2.373001776
]



fig, ax = plt.subplots()

# print len(groups)
x_ind = [x + 1 for x in range(0, len(xlabs))]
# x_ind = range(0, len(xlabs))
# print x_ind



# ax.bar(x_ind, y, color='red', edgecolor='black', hatch="/", linewidth=1)
ax.bar(x_ind, y, color='#ADC2EB', edgecolor='black', hatch="/", linewidth=1)

ax.set_xticks(x_ind)
# ax.set_xticklabels(xlabs, rotation=90)
ax.set_xticklabels(xlabs, rotation=0)
ax.tick_params(axis='x',  pad=5, length=5, top='off')

# print range(1, len(xlabs))


# bold the axis line
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(1.5)


# # draw a horizontal line at 1.0
# ax.axhline(y=1.0, xmin= 0.0, xmax = x_ind[-1] + 1, color="k", ls="--")
    
#
# title
#
ax.set_ylabel(ylabel, fontsize = 13)
# plt.title(title)
        
aspectratio=0.5
ratio_default=(ax.get_xlim()[1]-ax.get_xlim()[0])/(ax.get_ylim()[1]-ax.get_ylim()[0])
ax.set_aspect(ratio_default*aspectratio)


fig.savefig(figname + '.pdf',  dpi=300, transparent = True, bbox_inches='tight')
# fig.savefig(figname + '.png',  dpi=300, transparent = True, bbox_inches='tight')
# fig.savefig(figname + '.svg',  format="svg", transparent = True, bbox_inches='tight')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/leiming/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:1298: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if aspect == 'normal':
# /home/leiming/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_base.py:1303: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif aspect in ('equal', 'auto'):
